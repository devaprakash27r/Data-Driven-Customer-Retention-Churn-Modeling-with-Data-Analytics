# %%
# Data cleaning 

import pandas as pd

Raw_Dataset = pd.read_csv('Raw_Dataset.CSV')  # Getting the data from the raw dataset csv file

Raw_Dataset.head()
# Out:
#   customer_id              customer_name  gender  senior_citizen partner  \
# 0    CUST0001                   John doe    male               0     yes
# 1    CUST0002             Lauren Vaughan  female               1     NaN
# 2    CUST0003  Mrs. Elizabeth Turner DDS    MALE               1     NaN
# 3    CUST0004            Tiffany Johnson  FEMALE               1     NaN
# 4    CUST0005            Dr. Janice Berg  FEMALE               1      NO
#
#   dependents  tenure        contract paperless_billing    payment_method  ...  \
# 0         no      64  month to month               Yes  Electronic Check  ...
# 1        NaN      25  month to month               YES               NaN  ...
# 2         No      61        One year                No  Electronic Check  ...
# 3        Yes      49             NaN               YES               NaN  ...
# 4        Yes      47             NaN                No               NaN  ...
#
#   phone_service    multiple_lines internet_service online_security  \
# 0            No  no phone service              DSL             NaN
# 1            No               NaN      NO INTERNET             NaN
# 2           NaN  no phone service      NO INTERNET             NaN
# 3            No                No              DSL             Yes
# 4            No               NaN              NaN             NaN
#
#   online_backup device_protection tech_support streaming_tv streaming_movies  \
# 0           NaN               NaN          NaN          NaN              NaN
# 1           Yes               NaN          NaN          NaN              NaN
# 2           NaN                No          NaN          NaN               No
# 3            No               NaN          NaN          NaN              NaN
# 4           NaN                No          Yes          NaN               No
#
#   churn
# 0   yes
# 1   NaN
# 2   NaN
# 3   Yes
# 4   yes
#
# [5 rows x 22 columns]

# %%
Raw_Dataset.info() # To see the non-null values in the columns of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        1500 non-null   object
#  1   customer_name      1500 non-null   object
#  2   gender             1202 non-null   object
#  3   senior_citizen     1500 non-null   int64
#  4   partner            1208 non-null   object
#  5   dependents         771 non-null    object
#  6   tenure             1500 non-null   int64
#  7   contract           1188 non-null   object
#  8   paperless_billing  1218 non-null   object
#  9   payment_method     1191 non-null   object
#  10  monthly_charges    1012 non-null   object
#  11  total_charges      736 non-null    object
#  12  phone_service      1007 non-null   object
#  13  multiple_lines     1127 non-null   object
#  14  internet_service   1210 non-null   object
#  15  online_security    1015 non-null   object
#  16  online_backup      1031 non-null   object
#  17  device_protection  989 non-null    object
#  18  tech_support       988 non-null    object
#  19  streaming_tv       762 non-null    object
#  20  streaming_movies   770 non-null    object
#  21  churn              986 non-null    object
# dtypes: int64(2), object(20)
# memory usage: 257.9+ KB

# %%
# To know about the null-values count for each column
print("The total null values are")
print(Raw_Dataset.isnull().sum())
# Out:
# The total null values are
# customer_id            0
# customer_name          0
# gender               298
# senior_citizen         0
# partner              292
# dependents           729
# tenure                 0
# contract             312
# paperless_billing    282
# payment_method       309
# monthly_charges      488
# total_charges        764
# phone_service        493
# multiple_lines       373
# internet_service     290
# online_security      485
# online_backup        469
# device_protection    511
# tech_support         512
# streaming_tv         738
# streaming_movies     730
# churn                514
# dtype: int64

# %%
# .describe() will give the descriptive measures of the dataset 
Raw_Dataset.describe(include='all')
# Out:
#        customer_id customer_name  gender  senior_citizen partner dependents  \
# count         1500          1500    1202     1500.000000    1208        771
# unique        1500          1481       5             NaN       5          3
# top       CUST0001    Mark Adams  female             NaN     YES        Yes
# freq             1             2     312             NaN     334        416
# mean           NaN           NaN     NaN        0.504000     NaN        NaN
# std            NaN           NaN     NaN        0.500151     NaN        NaN
# min            NaN           NaN     NaN        0.000000     NaN        NaN
# 25%            NaN           NaN     NaN        0.000000     NaN        NaN
# 50%            NaN           NaN     NaN        1.000000     NaN        NaN
# 75%            NaN           NaN     NaN        1.000000     NaN        NaN
# max            NaN           NaN     NaN        1.000000     NaN        NaN
#
#              tenure        contract paperless_billing    payment_method  ...  \
# count   1500.000000            1188              1218              1191  ...
# unique          NaN               4                 4                 4  ...
# top             NaN  month to month               YES  Electronic Check  ...
# freq            NaN             306               322               308  ...
# mean      36.576000             NaN               NaN               NaN  ...
# std       20.891095             NaN               NaN               NaN  ...
# min        0.000000             NaN               NaN               NaN  ...
# 25%       19.000000             NaN               NaN               NaN  ...
# 50%       37.000000             NaN               NaN               NaN  ...
# 75%       55.000000             NaN               NaN               NaN  ...
# max       72.000000             NaN               NaN               NaN  ...
#
#        phone_service multiple_lines internet_service online_security  \
# count           1007           1127             1210            1015
# unique             2              3                4               2
# top               No             No               No             Yes
# freq             507            409              325             520
# mean             NaN            NaN              NaN             NaN
# std              NaN            NaN              NaN             NaN
# min              NaN            NaN              NaN             NaN
# 25%              NaN            NaN              NaN             NaN
# 50%              NaN            NaN              NaN             NaN
# 75%              NaN            NaN              NaN             NaN
# max              NaN            NaN              NaN             NaN
#
#        online_backup device_protection tech_support streaming_tv  \
# count           1031               989          988          762
# unique             2                 2            2            2
# top               No                No          Yes          Yes
# freq             525               524          513          391
# mean             NaN               NaN          NaN          NaN
# std              NaN               NaN          NaN          NaN
# min              NaN               NaN          NaN          NaN
# 25%              NaN               NaN          NaN          NaN
# 50%              NaN               NaN          NaN          NaN
# 75%              NaN               NaN          NaN          NaN
# max              NaN               NaN          NaN          NaN
#
#        streaming_movies churn
# count               770   986
# unique                2     4
# top                 Yes    No
# freq                393   284
# mean                NaN   NaN
# std                 NaN   NaN
# min                 NaN   NaN
# 25%                 NaN   NaN
# 50%                 NaN   NaN
# 75%                 NaN   NaN
# max                 NaN   NaN
#
# [11 rows x 22 columns]

# %%
# Using loop to get the first 10 unique values for each column by .unique()[:10]
for col in Raw_Dataset.columns:
    print(f"{col}: {Raw_Dataset[col].unique()[:10]}")
# Out:
# customer_id: ['CUST0001' 'CUST0002' 'CUST0003' 'CUST0004' 'CUST0005' 'CUST0006'
#  'CUST0007' 'CUST0008' 'CUST0009' 'CUST0010']
# customer_name: ['John doe' 'Lauren Vaughan' 'Mrs. Elizabeth Turner DDS' 'Tiffany Johnson'
#  'Dr. Janice Berg' 'Daniel Russell MD' 'Daniel Bradshaw' 'Willie Walton'
#  'Patricia Lopez' 'William Munoz']
# gender: ['male' 'female' 'MALE' 'FEMALE' 'Male' nan]
# senior_citizen: [0 1]
# partner: ['yes' nan 'NO' 'No' 'YES' 'Yes']
# dependents: ['no' nan 'No' 'Yes']
# tenure: [64 25 61 49 47 58 31  2 66 19]
# contract: ['month to month' 'One year' nan 'Month-to-month' 'Two Year']
# paperless_billing: ['Yes' 'YES' 'No' nan 'NO']
# payment_method: ['Electronic Check' nan 'Bank Transfer' 'Mailed check'
#  'Credit card (automatic)']
# monthly_charges: [nan 'twenty' '115.37' '62.59' '69.88' '34.66' '84.57' '31.20' '67.42'
#  '112.43']
# total_charges: [nan '2698.62' '5180.88' '1,000.50' '459.00' '515.69' '8401.12' '4935.08'
#  '1619.09' '2997.92']
# phone_service: ['No' nan 'Yes']
# multiple_lines: ['no phone service' nan 'No' 'Yes']
# internet_service: ['DSL' 'NO INTERNET' nan 'Fiber optic' 'No']
# online_security: [nan 'Yes' 'No']
# online_backup: [nan 'Yes' 'No']
# device_protection: [nan 'No' 'Yes']
# tech_support: [nan 'Yes' 'No']
# streaming_tv: [nan 'No' 'Yes']
# streaming_movies: [nan 'No' 'Yes']
# churn: ['yes' nan 'Yes' 'No' 'no']

# %%
# Creating a list for column names to feed in the function to normalise them 
columns = [
    'gender',
    'partner',
    'dependents',
    'contract',
    'paperless_billing',
    'payment_method',
    'monthly_charges',
    'total_charges',
    'phone_service',
    'multiple_lines',
    'internet_service',
    'online_security',
    'online_backup',
    'device_protection',
    'tech_support',
    'streaming_tv',
    'streaming_movies',
    'churn'
] # columns to change only 
print(columns)
# Out:
# ['gender', 'partner', 'dependents', 'contract', 'paperless_billing', 'payment_method', 'monthly_charges', 'total_charges', 'phone_service', 'multiple_lines', 'internet_service', 'online_security', 'online_backup', 'device_protection', 'tech_support', 'streaming_tv', 'streaming_movies', 'churn']

# %%
# Creating a function definition for cleaning the column data
def to_normalise_col(raw_data, col_names):
    for col in col_names:
        raw_data[col] = raw_data[col].astype(str).str.strip().str.lower().replace({
        'yes':'yes', 'no':'no', 'none':None, 'nan':None,'':None})
        print(raw_data[col].unique()[:10])
    return raw_data  # You must return df if you're assigning it to Raw_Dataset

Raw_Dataset= to_normalise_col(Raw_Dataset, columns)
# Out:
# ['male' 'female' None]
# ['yes' None 'no']
# ['no' None 'yes']
# ['month to month' 'one year' None 'month-to-month' 'two year']
# ['yes' 'no' None]
# ['electronic check' None 'bank transfer' 'mailed check'
#  'credit card (automatic)']
# [None 'twenty' '115.37' '62.59' '69.88' '34.66' '84.57' '31.20' '67.42'
#  '112.43']
# [None '2698.62' '5180.88' '1,000.50' '459.00' '515.69' '8401.12' '4935.08'
#  '1619.09' '2997.92']
# ['no' None 'yes']
# ['no phone service' None 'no' 'yes']
# ['dsl' 'no internet' None 'fiber optic' 'no']
# [None 'yes' 'no']
# [None 'yes' 'no']
# [None 'no' 'yes']
# [None 'yes' 'no']
# [None 'no' 'yes']
# [None 'no' 'yes']
# ['yes' None 'no']

# %%
# Changing the values 
Raw_Dataset['multiple_lines']=Raw_Dataset['multiple_lines'].replace({'no phone service':'no'})

Raw_Dataset['internet_service']=Raw_Dataset['internet_service'].replace({'no internet':'none'})

# %%
# Summary of nulls and uniques
print("Nulls:\n", Raw_Dataset.isnull().sum())

for col in columns:
    print(f"{col}: {Raw_Dataset[col].unique()}")
# Out:
# Nulls:
#  customer_id            0
# customer_name          0
# gender               298
# senior_citizen         0
# partner              292
# dependents           729
# tenure                 0
# contract             312
# paperless_billing    282
# payment_method       309
# monthly_charges      488
# total_charges        764
# phone_service        493
# multiple_lines       373
# internet_service     290
# online_security      485
# online_backup        469
# device_protection    511
# tech_support         512
# streaming_tv         738
# streaming_movies     730
# churn                514
# dtype: int64
# gender: ['male' 'female' None]
# partner: ['yes' None 'no']
# dependents: ['no' None 'yes']
# contract: ['month to month' 'one year' None 'month-to-month' 'two year']
# paperless_billing: ['yes' 'no' None]
# payment_method: ['electronic check' None 'bank transfer' 'mailed check'
#  'credit card (automatic)']
# monthly_charges: [None 'twenty' '115.37' '62.59' '69.88' '34.66' '84.57' '31.20' '67.42'
#  '112.43' '31.90' '100.64' '71.87' '48.71' '44.53' '104.70' '31.68'
#  '39.83' '52.64' '112.68' '94.70' '78.95' '44.59' '87.80' '100.96' '63.77'
#  '24.49' '18.35' '24.76' '101.17' '107.08' '40.35' '75.68' '26.50' '51.28'
#  '82.47' '30.00' '91.94' '69.40' '59.60' '83.39' '38.99' '94.79' '109.19'
#  '68.32' '38.23' '70.43' '27.29' '74.68' '115.92' '96.37' '27.24' '39.25'
#  '116.84' '68.01' '107.97' '51.66' '107.44' '53.46' '89.51' '62.11'
#  '119.62' '44.19' '63.15' '43.39' '43.94' '86.46' '81.07' '61.31' '18.94'
#  '66.22' '58.80' '78.33' '108.66' '99.86' '118.85' '96.47' '112.84'
#  '65.01' '92.16' '52.93' '117.80' '118.03' '68.94' '71.86' '31.82' '54.87'
#  '72.37' '117.49' '69.58' '24.28' '46.24' '21.38' '102.84' '26.02'
#  '114.06' '78.51' '28.18' '100.59' '44.73' '43.42' '33.55' '74.58' '22.51'
#  '44.47' '115.44' '107.68' '103.72' '89.49' '21.97' '88.28' '114.64'
#  '25.28' '38.32' '32.66' '106.85' '40.25' '59.14' '40.27' '112.31' '45.21'
#  '101.65' '62.67' '58.54' '62.29' '106.50' '56.40' '84.74' '118.01'
#  '69.64' '73.67' '24.03' '109.20' '85.01' '114.43' '117.15' '58.47'
#  '90.68' '47.13' '45.23' '95.89' '104.78' '86.05' '24.24' '63.04' '43.93'
#  '100.37' '118.93' '46.17' '45.19' '67.27' '23.21' '65.41' '95.78' '64.77'
#  '111.39' '81.80' '36.43' '21.15' '107.34' '82.42' '95.40' '110.62'
#  '45.76' '85.02' '115.51' '102.91' '30.44' '76.65' '59.53' '60.63' '97.22'
#  '112.26' '80.74' '98.38' '64.52' '84.23' '99.27' '56.94' '114.28' '56.64'
#  '84.76' '36.04' '32.39' '102.85' '43.06' '18.10' '30.03' '96.73' '40.85'
#  '111.83' '109.89' '65.14' '115.62' '60.13' '78.56' '69.16' '18.49'
#  '28.33' '29.14' '69.65' '88.51' '109.99' '95.28' '45.46' '51.81' '60.00'
#  '87.59' '78.12' '55.96' '69.77' '110.17' '82.49' '20.91' '60.85' '28.79'
#  '80.27' '79.33' '94.30' '92.96' '112.29' '88.48' '60.39' '62.75' '35.32'
#  '62.91' '104.21' '114.53' '101.76' '104.48' '23.44' '79.08' '68.35'
#  '286.19' '1244.45' '4524.38' '4382.20' '1766.65' '2605.68' '1434.86'
#  '2660.08' '1004.29' '160.61' '3441.05' '136.42' '568.83' '4390.82'
#  '1056.07' '2895.08' '699.26' '2645.13' '1795.31' '3264.08' '2549.13'
#  '2863.54' '6354.22' '3055.84' '4804.94' '1192.14' '3792.91' '1741.43'
#  '5846.80' '5449.22' '1017.28' '1965.41' '3033.73' '3747.28' '5084.45'
#  '2083.55' '4567.66' '704.40' '248.23' '6151.43' '2964.55' '1954.63'
#  '5468.33' '58.00' '4019.85' '138.68' '4126.18' '177.89' '5986.45'
#  '2792.91' '320.68' '80.78' '1765.39' '6246.48' '3941.22' '3965.53'
#  '427.54' '355.26' '1198.34' '2333.61' '5211.27' '1345.56' '1743.88'
#  '1815.75' '3596.25' '565.27' '2196.92' '1588.74' '2186.50' '208.18'
#  '156.49' '4026.22' '810.15' '4058.86' '2803.35' '3758.06' '2029.13'
#  '4474.32' '2090.78' '2961.62' '3095.65' '3154.44' '3663.32' '3747.47'
#  '4597.48' '3752.74' '3487.72']
# phone_service: ['no' None 'yes']
# multiple_lines: ['no' None 'yes']
# internet_service: ['dsl' 'none' None 'fiber optic' 'no']
# online_security: [None 'yes' 'no']
# online_backup: [None 'yes' 'no']
# device_protection: [None 'no' 'yes']
# tech_support: [None 'yes' 'no']
# streaming_tv: [None 'no' 'yes']
# streaming_movies: [None 'no' 'yes']
# churn: ['yes' None 'no']

# %%
# Changing the monthly_charges and total_charges Datatypes

print(Raw_Dataset['monthly_charges'].unique()[:10])

print(Raw_Dataset['total_charges'].unique()[:10])
# Out:
# [None 'twenty' '115.37' '62.59' '69.88' '34.66' '84.57' '31.20' '67.42'
#  '112.43']
# [None '2698.62' '5180.88' '1,000.50' '459.00' '515.69' '8401.12' '4935.08'
#  '1619.09' '2997.92']

# %%
# Creating function definition for cleaning the datatypes of numeric columns

def numeric_col_cleaning(raw_data, col_name):
     # Remove commas, strip spaces, and replace blank strings with NaN
    raw_data[col_name] = (raw_data[col_name]
        .astype(str)
        .str.replace(',', '', regex=False)
        .str.strip()
        .replace({
                '': None,
                'none': None,
                'null': None,
                'nan': None,
                'NaN': None,
                'NA': None
        })                
        )
    # Convert to float with errors='coerce' (invalids become NaN)
    raw_data[col_name] = pd.to_numeric(raw_data[col_name], errors='coerce')
    return raw_data

Raw_Dataset = numeric_col_cleaning(Raw_Dataset, 'monthly_charges') # Function Calling with monthly_charges
Raw_Dataset = numeric_col_cleaning(Raw_Dataset, 'total_charges') # Function Calling with total_charges

# Impute with Median for missing values 
Raw_Dataset['monthly_charges'] = Raw_Dataset['monthly_charges'].fillna(Raw_Dataset['monthly_charges'].median())
Raw_Dataset['total_charges'] = Raw_Dataset['total_charges'].fillna(Raw_Dataset['total_charges'].median())

# Summary and checking 
print(Raw_Dataset[['monthly_charges', 'total_charges']].dtypes)
print(Raw_Dataset[['monthly_charges', 'total_charges']].head(10))
print(Raw_Dataset.isnull().sum()[['monthly_charges', 'total_charges']])
print(Raw_Dataset[['monthly_charges', 'total_charges']].describe())
# Out:
# monthly_charges    float64
# total_charges      float64
# dtype: object
#    monthly_charges  total_charges
# 0            67.59        1000.50
# 1            67.59        1000.50
# 2            67.59        1000.50
# 3           115.37        2698.62
# 4            67.59        5180.88
# 5            67.59        1000.50
# 6            62.59        1000.50
# 7            67.59        1000.50
# 8            67.59        1000.50
# 9            67.59        1000.50
# monthly_charges    0
# total_charges      0
# dtype: int64
#        monthly_charges  total_charges
# count      1500.000000    1500.000000
# mean         67.946033    1391.698240
# std          17.506917    1167.105297
# min          18.100000       0.000000
# 25%          67.590000    1000.500000
# 50%          67.590000    1000.500000
# 75%          67.590000    1000.500000
# max         119.870000    8401.120000

# %%
# Creating Cleaned Dataset
Cleaned_Dataset = Raw_Dataset.copy()

print(Cleaned_Dataset)
# Out:
#      customer_id              customer_name  gender  senior_citizen partner  \
# 0       CUST0001                   John doe    male               0     yes
# 1       CUST0002             Lauren Vaughan  female               1    None
# 2       CUST0003  Mrs. Elizabeth Turner DDS    male               1    None
# 3       CUST0004            Tiffany Johnson  female               1    None
# 4       CUST0005            Dr. Janice Berg  female               1      no
# ...          ...                        ...     ...             ...     ...
# 1495    CUST1496             Daniel Rodgers    male               0    None
# 1496    CUST1497              Angela Cooper    male               1    None
# 1497    CUST1498               Richard Yang  female               0      no
# 1498    CUST1499                Steve Fritz  female               1     yes
# 1499    CUST1500             Victoria Munoz    male               1      no
#
#      dependents  tenure        contract paperless_billing  \
# 0            no      64  month to month               yes
# 1          None      25  month to month               yes
# 2            no      61        one year                no
# 3           yes      49            None               yes
# 4           yes      47            None                no
# ...         ...     ...             ...               ...
# 1495        yes      67        one year                no
# 1496       None       8  month-to-month              None
# 1497        yes       7        one year                no
# 1498        yes      34        two year               yes
# 1499       None      13  month-to-month               yes
#
#                payment_method  ...  phone_service  multiple_lines  \
# 0            electronic check  ...             no              no
# 1                        None  ...             no            None
# 2            electronic check  ...           None              no
# 3                        None  ...             no              no
# 4                        None  ...             no            None
# ...                       ...  ...            ...             ...
# 1495             mailed check  ...           None            None
# 1496            bank transfer  ...           None             yes
# 1497  credit card (automatic)  ...             no              no
# 1498         electronic check  ...            yes             yes
# 1499             mailed check  ...             no              no
#
#      internet_service online_security online_backup device_protection  \
# 0                 dsl            None          None              None
# 1                none            None           yes              None
# 2                none            None          None                no
# 3                 dsl             yes            no              None
# 4                None            None          None                no
# ...               ...             ...           ...               ...
# 1495      fiber optic             yes            no              None
# 1496      fiber optic            None           yes               yes
# 1497               no             yes           yes                no
# 1498               no            None          None              None
# 1499             none            None          None                no
#
#      tech_support streaming_tv streaming_movies churn
# 0            None         None             None   yes
# 1            None         None             None  None
# 2            None         None               no  None
# 3            None         None             None   yes
# 4             yes         None               no   yes
# ...           ...          ...              ...   ...
# 1495         None         None              yes    no
# 1496          yes         None              yes   yes
# 1497          yes           no               no   yes
# 1498          yes           no             None    no
# 1499           no         None             None   yes
#
# [1500 rows x 22 columns]

# %%
# Exporting a CSV file for the cleaned dataset
Cleaned_Dataset.to_csv('Cleaned_Dataset.CSV', index=False)
